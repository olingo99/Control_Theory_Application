# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import minimize
from datetime import datetime

import package_DBR
from package_DBR import myRound, FOPDT,SOPDT

# %% [markdown]
# # Load Data

# %%
nameFile = 'Open_loop_experiment_on_MV_2022-03-06-15h20.txt'
titleName = nameFile.split('.')[0]    
data = pd.read_csv('Data/' + nameFile)
t = data['t'].values - data['t'].values[0]
MV = data['MV'].values
PV = data['PV'].values
DV = data['DV'].values

# %% [markdown]
# # Clean Data

# %%
    tstep = np.argwhere(np.diff(MV) != 0)
    tstep = tstep[0][0]
    tm = t[tstep:]
    tm = tm - tm[0]    
    MVstep = MV[tstep + 1] - MV[tstep]
    MVm = MV[tstep:]
    PVm = PV[tstep:]
    PVm = (PVm - PVm[0])/MVstep
    MVm = (MVm - MVm[0])/MVstep 
    
    K= 0.6653630722784627
    T= 164.56082833946328
    theta=0.9999877287768981
    Ts=1
    
    K2= 0.6622098035196895
    T1= 162.66105529973166
    T2= 0.008654852911528323
    theta_2= 1.316831668876381

# %% [markdown]
# # Plot experimental and simulated data

# %%
PVSim_1 = FOPDT(MVm,K,T,theta,Ts)
PVSim_2 = SOPDT(MVm,K2,T1,T2,theta_2,Ts)

plt.figure(figsize = (22,20))
plt.title('Step response')

plt.step(tm,MVm,'black',linewidth=2,label='Cleaned MV',where='post')
plt.step(tm,PVm,'g-',linewidth=2,label='Cleaned experimental data',where='post')
plt.step(tm,PVSim_1,'r-',linewidth=2,label='Identified first order plus delay response',where='post')
plt.step(tm,PVSim_2,'b-',linewidth=2,label='Identified second order plus delay response',where='post')
plt.ylabel('Value of PV')
plt.xlabel('Time [s]')
plt.legend(loc='best')
